# %%
import numpy as np
import pandas as pd
import pandas_profiling 
import matplotlib.pyplot as plt
from scipy import misc

# %%
m=pd.read_csv('https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/Advertising.csv')

# %%
m
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
plt.plot(m)
plt.show()

# %%
pandas_profiling.ProfileReport(m)
# Out:
# Tab(children=(HTML(value='<div id="overview-content" class="row variable spacing">\n    <div class="row">\n   …
# Report generated with <a href="https://github.com/pandas-profiling/pandas-profiling">pandas-profiling</a>.

# %%
x=m['TV']
y=m['Sales']

# %%
x
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
plt.scatter(x,y)
plt.figure(figsize=(16,9))

# %%
from scipy import stats
slope,intercept,r_value,p_value,std_error=stats.linregress(x,y)

# %%
print("slope of the equation is:{}".format(slope))
# Out:
# slope of the equation is:0.04753664043301969

# %%
print("intercept of the equation is:{}".format(intercept))
# Out:
# intercept of the equation is:7.032593549127704

# %%
print("r_square is:{}".format(r_value**2))
# Out:
# r_square is:0.6118750508500705

# %%
print("p_value is:{}".format(p_value))
# Out:
# p_value is:1.4673897001948433e-42

# %%
print("standerd error is:{}".format(std_error))
# Out:
# standerd error is:0.0026906071877968707

# %%
plt.scatter(x,y,label='original data')
plt.plot(x,slope*x+intercept,'r',label='predicted data')
plt.legend()

# %%
a=m['Newspaper']
b=m['Sales']

# %%
plt.scatter(x,y)
plt.figure(figsize=(16,9))

# %%
slope,intercept,r_value,p_value,std_error=stats.linregress(a,b)

# %%
print("slope of the equation is:{}".format(slope))
# Out:
# slope of the equation is:0.05469309847227331

# %%
print("intercept of the equation is:{}".format(intercept))
# Out:
# intercept of the equation is:12.351407069278162

# %%
print("r_square is:{}".format(r_value**2))
# Out:
# r_square is:0.05212044544430501

# %%
print("p_value is:{}".format(p_value))
# Out:
# p_value is:0.0011481958688882112

# %%
print("standerd error is:{}".format(std_error))
# Out:
# standerd error is:0.016575721876358154

# %%
plt.scatter(a,b,label='original data')
plt.plot(a,slope*a+intercept,'r',label='predicted data')
plt.legend()

# %%
c=m['Radio']
d=m['Sales']

# %%
plt.scatter(c,d)
plt.figure(figsize=(16,9))

# %%
slope,intercept,r_value,p_value,std_error=stats.linregress(c,d)

# %%
print("slope of the equation is:{}".format(slope))
# Out:
# slope of the equation is:0.20249578339243954

# %%
print("intercept of the equation is:{}".format(intercept))
# Out:
# intercept of the equation is:9.311638095158287

# %%
print("r_square is:{}".format(r_value**2))
# Out:
# r_square is:0.332032455445295

# %%
print("p_value is:{}".format(p_value))
# Out:
# p_value is:4.354966001766976e-19

# %%
print("standerd error is:{}".format(std_error))
# Out:
# standerd error is:0.02041130636009063

# %%
plt.scatter(c,d,label='original data')
plt.plot(c,slope*c+intercept,'r',label='predicted data')
plt.legend()
